# %%
# 함수(Function
def fun():
    a = 5
    b = 6
    c = 8
    return a, b, c
x, y, z = fun()
print (f"x:{x}, y:{y}, z:{z}")

a = []
for i in range(5):
    a.append(i)
print (a)
b = []

b.extend(range(5))
print (b)

# %%
states = ["ArithmeticError", "AssertionError", "AttributeError", "EOFError", "FloatingPointError",
          "GeneratorExit", "ImportError", "IndexError", "KeyError", "KeyboardInterrupt", "MemoryError"]

import re

def clean_strings(strings):
    result = []
    for value in strings:
        value = value.strip()
        value = re.sub("[!#?]", "", value)
        value = value.title()
        result.append(value)
    return result
clean_strings(states)

# %%
def squares(n=10):
    print (f"=== Generating squares from 1 to {n ** 2} ===")
    for i in range(1, n+1):
        yield i ** 2
        
gen = squares()
print (gen)
        
for x in gen:
    print (f"{x}", end=" ")

# %%
total = 0
for i in range(100):
    total = total + (i ** 2)
print (total)

# %%
def attempt_float(c):
    try:
        return float(c)
    except ValueError:
        return c
    
attempt_float("3.14159")
attempt_float("not a number")
